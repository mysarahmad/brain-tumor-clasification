# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
directory="../input/brain-tumor-classification-mri/Training"
categories=["glioma_tumor","meningioma_tumor","pituitary_tumor","no_tumor"]

# %%
img_size=100
data=[]
for category in categories:
    folder=os.path.join(directory,category)
    label=categories.index(category)
    for img in os.listdir(folder):
        img_path=os.path.join(folder,img)
        img_arr=cv2.imread(img_path)
        img_arr=cv2.resize(img_arr,(img_size,img_size))
        data.append([img_arr,label])

# %%
x=[]
y=[]
for features,labels in data:
    x.append(features)
    y.append(labels)

# %%
import numpy as np

# %%
x=np.array(x)
y=np.array(y)

# %%
x.shape
# Out:
# (2870, 100, 100, 3)

# %%
x=x/255

# %% [markdown]
# ## modelling

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense

# %%
model=Sequential()

# %%
model.add(Conv2D(64,(3,3), activation="relu"))
model.add(MaxPool2D((2,2)))

# %%
model.add(Conv2D(64,(3,3), activation="relu"))
model.add(MaxPool2D((2,2)))

# %%
model.add(Flatten())

# %%
x.shape[1:]
# Out:
# (100, 100, 3)

# %%
model.add(Dense(units=128,activation='sigmoid',input_dim=x.shape[1:]))

# %%
model.add(Dense(units=4,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x,y,epochs=5,validation_split=0.1)
# Out:
# Epoch 1/5
# 81/81 [==============================] - 24s 287ms/step - loss: 0.8778 - accuracy: 0.6403 - val_loss: 2.5946 - val_accuracy: 0.0732
# Epoch 2/5
# 81/81 [==============================] - 23s 290ms/step - loss: 0.5027 - accuracy: 0.8022 - val_loss: 1.6117 - val_accuracy: 0.3972
# Epoch 3/5
# 81/81 [==============================] - 23s 290ms/step - loss: 0.3102 - accuracy: 0.8835 - val_loss: 2.1580 - val_accuracy: 0.3554
# Epoch 4/5
# 81/81 [==============================] - 23s 287ms/step - loss: 0.1994 - accuracy: 0.9292 - val_loss: 2.0344 - val_accuracy: 0.4007
# Epoch 5/5
# 81/81 [==============================] - 23s 289ms/step - loss: 0.1260 - accuracy: 0.9644 - val_loss: 1.3367 - val_accuracy: 0.5436
